# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
base_url = "https://raw.githubusercontent.com/pranta-iitp/Real-Estate-Property-Price-Prediction-Project/main/cleaned_flats.csv"
df_flats = pd.read_csv(base_url)
base_url = "https://raw.githubusercontent.com/pranta-iitp/Real-Estate-Property-Price-Prediction-Project/main/cleaned_houses.csv"
df_houses = pd.read_csv(base_url)

# %%
df = pd.concat([df_flats,df_houses],ignore_index=True)

# %%
df['society'].value_counts().head(3)
# Out:
# society
# independent     569
# tulip violet     75
# ss the leaf      74
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   pricePerSqft     3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           3961 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.head(3)
# Out:
#                   property_name property_type                 society  price  \
# 0  2 BHK Flat in Krishna Colony          flat  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar          flat            apna enclave   0.50
# 2           2 BHK Flat in Sohna          flat  tulsiani easy in homes   0.40
#
#    pricePerSqft   area                    areaWithType  bedRoom  bathroom  \
# 0        5000.0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2
# 1        7692.0  650.0  Carpet area: 650 (60.39 sq.m.)        2         2
# 2        6722.0  595.0  Carpet area: 595 (55.28 sq.m.)        2         2
#
#   balcony additionalRoom                             address  floorNum  \
# 0       1  not available    Krishna Colony, Gurgaon, Haryana       4.0
# 1       1  not available  46b, Ashok Vihar, Gurgaon, Haryana       1.0
# 2       3  not available             Sohna, Gurgaon, Haryana      12.0
#
#           facing    agePossession  \
# 0           west  1 to 5 Year Old
# 1           west     10+ Year Old
# 2  not available  0 to 1 Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### From property_name, extract sector and create a new column named 'sector'

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df['sector'].unique()
# Out:
# array(['Krishna Colony', 'Ashok Vihar', 'Sohna', 'Sector 61', 'Sector 92',
#        'Sector 36', 'Dwarka Expressway', 'Sector 104', 'Sector 88B',
#        'Sector 78', 'Sector 81', 'Sector 79', 'Sector 33', 'Sector 90',
#        'Sector 108', 'Sector 62', 'Sector 102', 'Sector 93',
#        'Sector-33 Sohna', 'Sector 89', 'Sector 113', 'Sector 65',
#        'Sector 48', 'Sector 37C', 'Sector 3', 'New Palam Vihar',
#        'Sector 43', 'Sector 88A', 'Sector 68', 'Sector 109', 'Sector 106',
#        'Sector 82', 'Ashok Vihar Phase 3 Extension', 'Sector 85',
#        'Sector 82A', 'DLF Phase 4', 'Sector 10A', 'Sector 1A IMT Manesar',
#        'Block A Surya Vihar', 'Sector 84', 'Sector 71', 'Sector-7 Hous',
#        'Sector 77', 'Sector 37D', 'Sector 67A', 'Sector 57', 'Sector 95',
#        'Sector 99A', 'Sector 103', 'Sector 49', 'Sector 30', 'Sector 86',
#        'Sector 66', 'Sector 15 Part 1', 'Laxman Vihar', 'Sector 22',
#        'Sector 63A', 'Sector 95A', 'Sector 52', 'Sector 67',
#        'Sushant Lok Phase 1', 'Sector 107', 'Sector 12A', 'Sohna Road',
#        'Ashok Vihar Phase 2', 'Rajiv Colony', 'Sector 2', 'Garauli Kalan',
#        'Bhawani Enclave', 'Sector 99', 'IFFCO Chowk', 'Palam Vihar',
#        'Sector 91', 'near sector 1 market', 'Sector 70', 'Sector 70A',
#        'Gwal Pahari', 'Sector 7', 'Malibu Town', 'Golf Course Road',
#        'Sector 4', 'Sector 54', 'Sector 111', 'Chakkarpur', 'Sector 41',
#        'Sector 12', 'Sector 73', 'Sector 36 Sohna', 'Sector 56',
#        'Sector 83', 'Sector 53', 'Sector 72', 'Sector 1 Imt Manesar',
#        'Sector 69', 'Sector 47', 'Sector 63', 'Sector 110', 'Kanahi',
#        'Sector-11 sohna', 'DLF Phase 5', 'Sector 9A', 'Sector 28',
#        'Sector 14', 'Nirvana Country', 'DLF Phase 2', 'Sector 59',
#        'DLF Phase 3', 'Heritage City', 'Sector 1', 'Sector 38',
#        'Sector 15', 'Ambience Island', 'Sector 112', 'Sector 45',
#        'Sector 74', 'Sector 60', 'Sector 51', 'Sector 50', 'Suncity',
#        'Sector 110 A', 'Sector 39', 'Sai Kunj', 'Manesar', 'sector 58',
#        'IMT Manesar', 'Sector 80', 'MG Road', 'Sector 55', 'Sultanpur',
#        'Sector 23A', 'Sector 36A', 'Civil L', 'Sector 76',
#        'New Colony, Sector 7', 'Sector 31', 'Lajpat Nagar', 'Sector 89 A',
#        'New', 'Sector 11', 'Sector 32', 'Surya Vihar',
#        'Near Pataudi Chowk', 'Cyber City', 'New Colony', 'Subhash Nagar',
#        'ats marigold', 'Sector-2 Sohna', 'Adarsh Nagar', 'Sector 37A',
#        'Sushant Lok Phase 3', 'Carterpuri Village', 'Valley View Estate',
#        'Shanti Nagar', 'Sushant Lok', 'Mehrauli  Road',
#        'Laxman Vihar Phase 2', 'Sector-5 Sohna', 'Faridabad Road',
#        'Sector 5 chowk', 'old delhi road, opp sector-14', 'Sector 21',
#        'Sector 5', 'Dayanand Colony', 'Samaspur',
#        'Nirvana country Pocket H', 'Patel Nagar', 'Surat Nagar 1',
#        'Sispal Vihar', 'Golf Course Ext Road', 'Shankar Vihar',
#        'New Palam Vihar Phase 2', 'Sector 24', 'Sector-35 Sohna',
#        'Bhondsi', 'Palam Vihar Extension', 'saroop garden rajendra park',
#        'Sector 4 Urban Estate', 'BPTP', 'Sector 105', 'South City 1',
#        'Sector 9', 'Sector 40', 'Dharam Colony', 'Rajendra Park',
#        'Godrej Aria , sector 79 ,', 'Sector 21A Faridabad', 'DLF Phase 1',
#        'B Block Sushant Lok Phase 1', 'New Palam Vihar Phase 1',
#        'Uppals Southend', 'Hsiidc Plot Sector 1 Imt Manesar',
#        'Sector 15 Part 2', 'Nars', 'C Block Sushant Lok Phase 1',
#        'Greenwood City', 'Sector 23', 'Sector 17C', 'Shivaji Nagar',
#        'Hira Nagar', 'Gopal Nagar, Garhi Ghasita, Sonipat',
#        'Jat Colony,Fazilpur/Taj Nagar Road', 'Sector 17A', 'Kheri',
#        'Madanpuri', 'Mohan Nagar', 'Daulatabad', 'Vishnu Garden',
#        'New Basti', 'Sector 8', 'Maruti Kunj', 'Laxmi Garden',
#        'Sector 9B', 'Saraswati Vihar', 'Bhora Kalan',
#        'near nand hospital', 'Shivpuri', 'Jyoti Park',
#        'Surat Nagar Phase 2', 'Rajiv Nagar', 'Arjun Nagar',
#        'Ashok Vihar Phase I', 'Block H Ashok Vihar Phase III Extension',
#        'Devilal Colony', 'Prem Nagar', 'Bhim Nagar', 'Surat Nagar',
#        'Gandhi Nagar', 'Khandsa', 'Ravi Nagar', 'URBAN ESTATE, SECTOR 5',
#        'West Rajiv Nagar', 'Near Khandsa Road', 'Sheetla Colony',
#        'Farukhnagar', 'Mianwali Colony', 'Part 3 Sector 5', 'Lucknow',
#        'Pataudi Road', 'Shakti Nagar', 'Baldev Nagar', 'Acharya Puri',
#        'Garhi Harsaru', 'Pratap Nagar', 'Manohar Nagar', 'Vir Nagar',
#        'Hno 13 Sagar enclave Sura', 'Sector 13', 'Ram Nagar',
#        'Block G Sector-57', 'Sector 17', 'Sector 6', 'Sector 3A',
#        'Om Nagar', 'Anand Garden, Sector-105', 'Jacobpura',
#        'Tekchand Nagar', 'Ashok Vihar Phase 3', "Ansal's Palam Vihar",
#        'Jacobpura Near Sadar Bazar', 'Shivji Park Colony',
#        'Udyog Vihar Phase 1', 'Mahalaxmi Garden, Rajendra Place',
#        'Rattan Garden', 'Sadar Bazar', 'Naharpur Rupa',
#        'Laxman Vihar, Railway Road,', 'sector-5 sheetla colony', 'Damdma',
#        ', Delhi NCR', 'New Jyoti Park', 'Sohna  Road', 'Mahavir pura',
#        'Sector 37B', 'G block DLF City Phase 1', 'Park View',
#        'ravi nager basai road', 'Begampur Khatola', 'Dhankot',
#        'Rajiv Chowk',
#        'devi lal colony gali no 12 gurgaon nr omkar public school',
#        'Alipur', 'Saraswati Enclave',
#        'Sec 3 Bhim Vihar Part 1 Bhimgher Kheri', 'Near euro',
#        'Bhimgarh Kheri Phase 3', 'HUDA Saraswati Vihar',
#        'laxmna vihar, phase 2', 'Sector 17B', 'Sector 46',
#        'Sushant Lok Phase 2', 'Ansal Plaza',
#        'A Block Sushant Lok Phase 1', 'Sector 27', 'B1 Block Sector 57',
#        'Mayfield Garden', 'Sector 42', 'Sector 26', 'South City',
#        'Rosewood', 'V Block DLF Phase 3', 'Bissar'], dtype=object)

# %%
df['sector'] = df['sector'].str.lower().str.strip()

# %%
# Filter the DataFrame to show rows that do not contain the word 'sector'
filtered_df = df[~df['sector'].str.contains('sector', case=False)]

# %%
filtered_df['sector'].unique()
# Out:
# array(['krishna colony', 'ashok vihar', 'sohna', 'dwarka expressway',
#        'new palam vihar', 'ashok vihar phase 3 extension', 'dlf phase 4',
#        'block a surya vihar', 'laxman vihar', 'sushant lok phase 1',
#        'sohna road', 'ashok vihar phase 2', 'rajiv colony',
#        'garauli kalan', 'bhawani enclave', 'iffco chowk', 'palam vihar',
#        'gwal pahari', 'malibu town', 'golf course road', 'chakkarpur',
#        'kanahi', 'dlf phase 5', 'nirvana country', 'dlf phase 2',
#        'dlf phase 3', 'heritage city', 'ambience island', 'suncity',
#        'sai kunj', 'manesar', 'imt manesar', 'mg road', 'sultanpur',
#        'civil l', 'lajpat nagar', 'new', 'surya vihar',
#        'near pataudi chowk', 'cyber city', 'new colony', 'subhash nagar',
#        'ats marigold', 'adarsh nagar', 'sushant lok phase 3',
#        'carterpuri village', 'valley view estate', 'shanti nagar',
#        'sushant lok', 'mehrauli  road', 'laxman vihar phase 2',
#        'faridabad road', 'dayanand colony', 'samaspur',
#        'nirvana country pocket h', 'patel nagar', 'surat nagar 1',
#        'sispal vihar', 'golf course ext road', 'shankar vihar',
#        'new palam vihar phase 2', 'bhondsi', 'palam vihar extension',
#        'saroop garden rajendra park', 'bptp', 'south city 1',
#        'dharam colony', 'rajendra park', 'dlf phase 1',
#        'b block sushant lok phase 1', 'new palam vihar phase 1',
#        'uppals southend', 'nars', 'c block sushant lok phase 1',
#        'greenwood city', 'shivaji nagar', 'hira nagar',
#        'gopal nagar, garhi ghasita, sonipat',
#        'jat colony,fazilpur/taj nagar road', 'kheri', 'madanpuri',
#        'mohan nagar', 'daulatabad', 'vishnu garden', 'new basti',
#        'maruti kunj', 'laxmi garden', 'saraswati vihar', 'bhora kalan',
#        'near nand hospital', 'shivpuri', 'jyoti park',
#        'surat nagar phase 2', 'rajiv nagar', 'arjun nagar',
#        'ashok vihar phase i', 'block h ashok vihar phase iii extension',
#        'devilal colony', 'prem nagar', 'bhim nagar', 'surat nagar',
#        'gandhi nagar', 'khandsa', 'ravi nagar', 'west rajiv nagar',
#        'near khandsa road', 'sheetla colony', 'farukhnagar',
#        'mianwali colony', 'lucknow', 'pataudi road', 'shakti nagar',
#        'baldev nagar', 'acharya puri', 'garhi harsaru', 'pratap nagar',
#        'manohar nagar', 'vir nagar', 'hno 13 sagar enclave sura',
#        'ram nagar', 'om nagar', 'jacobpura', 'tekchand nagar',
#        'ashok vihar phase 3', "ansal's palam vihar",
#        'jacobpura near sadar bazar', 'shivji park colony',
#        'udyog vihar phase 1', 'mahalaxmi garden, rajendra place',
#        'rattan garden', 'sadar bazar', 'naharpur rupa',
#        'laxman vihar, railway road,', 'damdma', ', delhi ncr',
#        'new jyoti park', 'sohna  road', 'mahavir pura',
#        'g block dlf city phase 1', 'park view', 'ravi nager basai road',
#        'begampur khatola', 'dhankot', 'rajiv chowk',
#        'devi lal colony gali no 12 gurgaon nr omkar public school',
#        'alipur', 'saraswati enclave',
#        'sec 3 bhim vihar part 1 bhimgher kheri', 'near euro',
#        'bhimgarh kheri phase 3', 'huda saraswati vihar',
#        'laxmna vihar, phase 2', 'sushant lok phase 2', 'ansal plaza',
#        'a block sushant lok phase 1', 'mayfield garden', 'south city',
#        'rosewood', 'v block dlf phase 3', 'bissar'], dtype=object)

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
#df['sector'] = df['sector'].str.replace('sohna road','sohna road')#new change
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')
# new changes
df['sector'] = df['sector'].str.replace('rajiv colony','sector 33')
df['sector'] = df['sector'].str.replace('garauli kalan','sector 37c')
df['sector'] = df['sector'].str.replace('bhawani enclave','sector 9')
df['sector'] = df['sector'].str.replace('iffco chowk','sector 29')
df['sector'] = df['sector'].str.replace('devi lal colony gali no 12 gurgaon nr omkar public school','sector 9a')
df['sector'] = df['sector'].str.replace('rosewood','sector 49')
df['sector'] = df['sector'].str.replace('mayfield garden','sector 51')
df['sector'] = df['sector'].str.replace('laxmna vihar','sector 3a')
df['sector'] = df['sector'].str.replace('saraswati enclave','sector 37')
df['sector'] = df['sector'].str.replace('om nagar','sector 11')
df['sector'] = df['sector'].str.replace('dhankot','sector 102')

df['sector'] = df['sector'].str.replace('surat nagar','sector 102')
df['sector'] = df['sector'].str.replace('surat nagar phase 2','sector 102')
df['sector'] = df['sector'].str.replace('surat nagar phase 1','sector 102')
df['sector'] = df['sector'].str.replace('surat nagar phase 3','sector 102')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('pratap nagar','sector 8')
df['sector'] = df['sector'].str.replace('mohan nagar','sector 67')
df['sector'] = df['sector'].str.replace('hira nagar','sector 11')
df['sector'] = df['sector'].str.replace('sheetla colony','sector 5')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 67')
df['sector'] = df['sector'].str.replace('sec 3 bhim vihar part 1 bhimgher kheri','sector 3')
df['sector'] = df['sector'].str.replace('manohar nagar','sector 8')
df['sector'] = df['sector'].str.replace('rattan garden','sector 7')
df['sector'] = df['sector'].str.replace('shankar vihar','sector 104')
df['sector'] = df['sector'].str.replace('kanahi','sector 45')
df['sector'] = df['sector'].str.replace('sispal vihar','sector 49')
df['sector'] = df['sector'].str.replace('gopal nagar, garhi ghasita, sonipat','sector 12')
df['sector'] = df['sector'].str.replace('acharya puri','sector 12')
df['sector'] = df['sector'].str.replace('udyog vihar phase 1','sector 20')
df['sector'] = df['sector'].str.replace('g block dlf city phase 1','sector 26')
df['sector'] = df['sector'].str.replace('jat colony,fazilpur/taj nagar road','sector 72')
df['sector'] = df['sector'].str.replace('ravi nager basai road','sector 9')
df['sector'] = df['sector'].str.replace('bhimgarh kheri phase 3','sector 3')
df['sector'] = df['sector'].str.replace('bhimgarh kheri phase 2','sector 3')
df['sector'] = df['sector'].str.replace('shanti nagar','sector 11')
df['sector'] = df['sector'].str.replace('shivji park colony','sector 10a')
df['sector'] = df['sector'].str.replace('ram nagar','sector 8')
df['sector'] = df['sector'].str.replace('cyber city','sector 24')
df['sector'] = df['sector'].str.replace('ambience island','sector 24')
df['sector'] = df['sector'].str.replace('manesar','sector 8')
df['sector'] = df['sector'].str.replace('sohna road','sector 33')

df.loc[df['society'] == 'suncity vatsal valley', 'sector'] = df.loc[df['society'] == 'suncity vatsal valley', 'sector'].str.replace('gwal pahari', 'sector 2')
df.loc[df['society'] == 'valley view estate', 'sector'] = df.loc[df['society'] == 'valley view estate', 'sector'].str.replace('gwal pahari', 'sector 58')
df.loc[df['society'] == 'paras quartier', 'sector'] = df.loc[df['society'] == 'paras quartier', 'sector'].str.replace('gwal pahari', 'sector 105')
df.loc[df['society'] == 'krrish provence estate', 'sector'] = df.loc[df['society'] == 'krrish provence estate', 'sector'].str.replace('gwal pahari', 'sector 2')
df.loc[df['society'] == 'bsf chs', 'sector'] = df.loc[df['society'] == 'bsf chs', 'sector'].str.replace('gwal pahari', 'sector 2')

df.loc[df['society'] == 'the cocoon', 'sector'] = df.loc[df['society'] == 'the cocoon', 'sector'].str.replace('dwarka expressway', 'sector 109')
df.loc[df['society'] == 'ramprastha city', 'sector'] = df.loc[df['society'] == 'ramprastha city', 'sector'].str.replace('dwarka expressway', 'sector 92')
df.loc[df['society'] == 'rattan vihar rajendra park', 'sector'] = df.loc[df['society'] == 'rattan vihar rajendra park', 'sector'].str.replace('dwarka expressway', 'sector 105')
df.loc[df['society'] == 'experion heartsong', 'sector'] = df.loc[df['society'] == 'experion heartsong', 'sector'].str.replace('dwarka expressway', 'sector 108')
df.loc[df['society'] == 'hero homes', 'sector'] = df.loc[df['society'] == 'hero homes', 'sector'].str.replace('dwarka expressway', 'sector 104 Hey Cortana')
df.loc[df['society'] == 'ansals highland park', 'sector'] = df.loc[df['society'] == 'ansals highland park', 'sector'].str.replace('dwarka expressway', 'sector 103')
df.loc[df['society'] == 'smart world one', 'sector'] = df.loc[df['society'] == 'smart world one', 'sector'].str.replace('dwarka expressway', 'sector 113')

# %%
df.sample(5)
# Out:
#                                       property_name property_type  \
# 3285        9 Bedroom House for sale in DLF Phase 2         house
# 3628  4 Bedroom House for sale in Sector 65 Gurgaon         house
# 2951                2 BHK Flat in Sector 79 Gurgaon          flat
# 2567                2 BHK Flat in Sector 90 Gurgaon          flat
# 3924  5 Bedroom House for sale in Sector 33 Gurgaon         house
#
#                        society     sector  price  pricePerSqft    area  \
# 3285               independent  sector 25  13.50       19286.0  7000.0
# 3628       emaar emerald hills  sector 65  12.50       34722.0  3600.0
# 2951        supertech araville  sector 79   0.80        6178.0  1295.0
# 2567               green court  sector 90   0.47        6811.0   690.0
# 3924  unitech uniworld resorts  sector 33  11.50       24573.0  4680.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 3285      Built Up area: 7000 (650.32 sq.m.)        9         9       0
# 3628             Plot area 400(334.45 sq.m.)        4         4      3+
# 2951  Super Built up area 1295(120.31 sq.m.)        2         2      3+
# 2567           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 3924             Plot area 520(434.79 sq.m.)        5         6      3+
#
#                additionalRoom  \
# 3285            not available
# 3628  servant room,study room
# 2951                   others
# 2567            not available
# 3924             servant room
#
#                                               address  floorNum  \
# 3285  Dlf City Phase 2, DLF Phase 2, Gurgaon, Haryana       1.0
# 3628       Villa, Sector 65 Gurgaon, Gurgaon, Haryana       2.0
# 2951       E-906, Sector 79 Gurgaon, Gurgaon, Haryana       9.0
# 2567              Sector 90 Gurgaon, Gurgaon, Haryana       0.0
# 3924              Sector 33 Gurgaon, Gurgaon, Haryana       4.0
#
#              facing    agePossession  \
# 3285           east  1 to 5 Year Old
# 3628           east  1 to 5 Year Old
# 2951  not available  0 to 1 Year Old
# 2567           east  0 to 1 Year Old
# 3924           east  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 3285                                                NaN
# 3628  ['Emerald Plaza Shopping Mall', 'Southern Peri...
# 2951  ['Petrol Pump Indian Oil', 'Petrol Pump', 'Rao...
# 2567  ['Baba Kanala Chowk', 'Pataudi Rd', 'Gurukul P...
# 3924  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stan...
#
#                                             description  \
# 3285  Best in class property available at dlf city p...
# 3628  Independent house for sale in emaar emerald hi...
# 2951  Residential apartment for sell.Located on 9th ...
# 2567  Park facing, only 04 flats on floor, both side...
# 3924  500 sqyd villas with front and rear lawns , pr...
#
#                                          furnishDetails  \
# 3285  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3628  ['6 AC', '1 Modular Kitchen', 'No Bed', 'No Ch...
# 2951                                                 []
# 2567  ['3 Fan', '1 Exhaust Fan', '7 Light', 'No AC',...
# 3924  ['5 Wardrobe', '6 Fan', '18 Light', 'No AC', '...
#
#                                                features  \
# 3285                                                NaN
# 3628                                                NaN
# 2951  ['Lift(s)', 'Swimming Pool', 'Park', 'Club hou...
# 2567  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3924  ['Private Garden / Terrace', 'High Ceiling Hei...
#
#                                                  rating
# 3285  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3628  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2951  ['Safety4 out of 5', 'Lifestyle3 out of 5', 'E...
# 2567  ['Green Area3 out of 5', 'Construction4 out of...
# 3924  ['Environment3 out of 5', 'Safety4 out of 5', ...

# %%
df['sector'].unique()
# Out:
# array(['sector 7', 'sector 3', 'sector 33', 'sector 61', 'sector 92',
#        'sector 36', 'sector 109', 'sector 104', 'sector 88b', 'sector 78',
#        'sector 81', 'sector 79', 'sector 90', 'sector 108', 'sector 62',
#        'sector 102', 'sector 93', 'sector 89', 'sector 113', 'sector 65',
#        'sector 48', 'sector 37c', 'new sector 2', 'sector 43',
#        'sector 88a', 'sector 68', 'sector 106', 'sector 82',
#        'sector 3 phase 3 extension', 'sector 85', 'sector 82a',
#        'sector 28', 'sector 10a', 'sector 8', 'block a sector 21',
#        'sector 84', 'sector 71', 'sector-7 hous', 'sector 77',
#        'sector 37d', 'sector 67a', 'sector 57', 'sector 95', 'sector 99a',
#        'sector 103', 'sector 49', 'sector 30', 'sector 86', 'sector 66',
#        'sector 15 part 1', 'sector 4', 'sector 22', 'sector 63a',
#        'sector 52', 'sector 67', 'sector 107', 'sector 12',
#        'sector 33 road', 'sector 3 phase 2', 'sector 2', 'sector 9',
#        'sector 99', 'sector 29', 'sector 91', 'near sector 1 market',
#        'sector 70', 'sector 70a', 'sector 47', 'golf course road',
#        'sector 54', 'sector 111', 'sector 41', 'sector 73', 'sector 56',
#        'sector 83', 'sector 53', 'sector 72', 'sector 69', 'sector 63',
#        'sector 110', 'sector 45', 'sector-11 sector 33', 'sector 9a',
#        'sector 14', 'sector 50', 'sector 25', 'sector 59', 'sector 24',
#        'heritage city', 'sector 105', 'sector 1', 'sector 38',
#        'sector 104 Hey Cortana', 'sector 15', 'sector 112', 'sector 74',
#        'sector 60', 'sector 51', 'sector 39', 'sai kunj', 'sector 58',
#        'gwal pahari', 'sector 80', 'sector 55', 'sultanpur', 'sector 23',
#        'sector 36a', 'civil l', 'sector 76', 'sector 7, sector 7',
#        'sector 31', 'lajpat nagar', 'new', 'sector 11', 'sector 32',
#        'sector 21', 'near pataudi chowk', 'ats marigold',
#        'sector-2 sector 33', 'sector 37a', 'carterpuri village',
#        'sushant lok', 'sector-5 sector 33', 'faridabad road',
#        'sector 5 chowk', 'old delhi road, opp sector-14', 'sector 5',
#        'sector 6', 'samaspur', 'sector 50 pocket h',
#        'golf course ext road', 'new sector 2 phase 2',
#        'sector-35 sector 33', 'saroop garden sector 105',
#        'sector 4 urban estate', 'bptp', 'sector 40',
#        'godrej aria , sector 79 ,', 'sector 21a faridabad', 'sector 26',
#        'new sector 2 phase 1', 'hsiidc plot sector 8', 'sector 15 part 2',
#        'nars', 'sector 17c', 'sector 17a', 'kheri', 'daulatabad',
#        'new basti', 'sector 9b', 'bhora kalan', 'near nand hospital',
#        'sector 102 phase 2', 'sector 13', 'sector 3 phase i',
#        'block h sector 3 phase iii extension', 'khandsa',
#        'urban estate, sector 5', 'west sector 13', 'near khandsa road',
#        'farukhnagar', 'part 3 sector 5', 'lucknow', 'pataudi road',
#        'sector 17', 'vir nagar', 'hno 13 sagar enclave sura',
#        'block g sector-57', 'anand garden, sector-105', 'tekchand nagar',
#        'sector 3 phase 3', "ansal's sector 2",
#        'sector 12 near sadar bazar', 'sector 20',
#        'mahasector 11, rajendra place', 'sadar bazar', 'naharpur rupa',
#        'sector 4, railway road,', 'sector-5 sector 5', 'damdma',
#        ', delhi ncr', 'new sector 7', 'sector 33  road', 'mahavir pura',
#        'sector 37b', 'park view', 'begampur khatola', 'rajiv chowk',
#        'alipur', 'sector 37', 'near euro', 'huda sector 28',
#        'sector 3a, phase 2', 'sector 17b', 'sector 46', 'sector 27',
#        'b1 block sector 57', 'sector 42', 'south city',
#        'v block sector 24', 'bissar'], dtype=object)

# %%
# Filter the DataFrame to show rows that do not contain the word 'sector'
filtered_df = df[~df['sector'].str.contains('sector', case=False)]

# %%
filtered_df['sector'].unique()
# Out:
# array(['golf course road', 'heritage city', 'sai kunj', 'gwal pahari',
#        'sultanpur', 'civil l', 'lajpat nagar', 'new',
#        'near pataudi chowk', 'ats marigold', 'carterpuri village',
#        'sushant lok', 'faridabad road', 'samaspur',
#        'golf course ext road', 'bptp', 'nars', 'kheri', 'daulatabad',
#        'new basti', 'bhora kalan', 'near nand hospital', 'khandsa',
#        'near khandsa road', 'farukhnagar', 'lucknow', 'pataudi road',
#        'vir nagar', 'hno 13 sagar enclave sura', 'tekchand nagar',
#        'sadar bazar', 'naharpur rupa', 'damdma', ', delhi ncr',
#        'mahavir pura', 'park view', 'begampur khatola', 'rajiv chowk',
#        'alipur', 'near euro', 'south city', 'bissar'], dtype=object)

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sector 33                     238
# sector 102                    116
# sector 85                     110
# sector 92                     106
# sector 69                      94
# sector 81                      90
# sector 65                      90
# sector 90                      90
# sector 109                     89
# sector 79                      80
# sector 104                     75
# sector 2                       73
# sector 83                      69
# sector 37d                     68
# sector 43                      67
# sector 86                      67
# sector 95                      66
# sector 50                      65
# sector 89                      64
# sector 108                     60
# sector 107                     60
# sector 56                      57
# sector 48                      56
# sector 70a                     54
# sector 37c                     54
# sector 70                      53
# sector 49                      52
# sector 84                      51
# sector 26                      51
# sector 67                      50
# sector 4                       49
# sector 28                      47
# sector 8                       46
# sector 103                     46
# sector 66                      46
# sector 113                     44
# sector 25                      43
# sector 82                      42
# sector 61                      42
# sector 7                       40
# sector 12                      40
# sector 106                     38
# sector 99a                     32
# sector 54                      31
# sector 72                      30
# sector 68                      30
# sector 77                      29
# sector 24                      27
# sector 71                      27
# sector 105                     27
# sector 11                      26
# sector 3                       26
# sector 57                      24
# sector 112                     24
# sector 14                      23
# sector 88a                     23
# sector 67a                     22
# sector 111                     22
# sector 22                      20
# sector 82a                     20
# sector 78                      19
# sector 110                     19
# sector 47                      19
# sector 74                      18
# sector 63a                     18
# sector 91                      17
# sector 62                      17
# sector 99                      16
# sector 9                       16
# sector 60                      15
# sector 63                      15
# sector 55                      14
# sector 53                      14
# sector 76                      14
# sector 52                      14
# sector 36a                     13
# sector 6                       13
# sector 23                      13
# sector 46                      13
# sector 31                      12
# sector 39                      12
# sector 9a                      12
# sector 33 road                 12
# sector 38                      12
# sector 93                      12
# sector 3 phase 3 extension     11
# sector 36                      11
# sector 41                      11
# sector 45                      10
# sector 58                      10
# sector 13                      10
# sector 3 phase 2                9
# sector 51                       9
# sector 10a                      9
# sector 5                        8
# sector 40                       8
# sector 59                       8
# sector 17                       8
# sector 21                       6
# sector 15                       6
# sector 1                        6
# new sector 2                    5
# sector 80                       5
# sector 30                       5
# new                             4
# sector 88b                      3
# sector 73                       3
# sector 17a                      3
# sector 17b                      3
# sector 27                       3
# Name: count, dtype: int64

# %%
df[(df['sector'] == 'new') | (df['sector'] == 'new sector 2')]
# Out:
#                                     property_name property_type  \
# 30                  2 BHK Flat in New Palam Vihar          flat
# 88                  2 BHK Flat in New Palam Vihar          flat
# 2045                    4 BHK Flat in New Gurgaon          flat
# 2803                    2 BHK Flat in New Gurgaon          flat
# 2842                2 BHK Flat in New Palam Vihar          flat
# 2895                    2 BHK Flat in New Gurgaon          flat
# 2960                    4 BHK Flat in New Gurgaon          flat
# 3168  2 Bedroom House for sale in New Palam Vihar         house
# 3274  3 Bedroom House for sale in New Palam Vihar         house
#
#                            society        sector  price  pricePerSqft    area  \
# 30             ompee k s residency  new sector 2   1.60       26936.0   594.0
# 88                         my home  new sector 2   0.28        3166.0   884.0
# 2045                        dlf 76           new   4.00       11428.0  3500.0
# 2803  takshila heights sector 37 c           new   0.67        5583.0  1200.0
# 2842                       my home  new sector 2   0.22        4400.0   500.0
# 2895                   green court           new   0.38        5507.0   690.0
# 2960                    sare homes           new   0.85        4786.0  1776.0
# 3168                       my home  new sector 2   0.34       12592.0   270.0
# 3274                   independent  new sector 2   1.00        8796.0  1137.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 30                        Carpet area: 66 (55.18 sq.m.)        2         2
# 88                       Carpet area: 900 (83.61 sq.m.)        2         1
# 2045                   Carpet area: 3500 (325.16 sq.m.)        4         4
# 2803             Super Built up area 1200(111.48 sq.m.)        2         2
# 2842                     Carpet area: 500 (46.45 sq.m.)        2         2
# 2895                      Carpet area: 690 (64.1 sq.m.)        2         2
# 2960                Super Built up area 1776(165 sq.m.)        4         4
# 3168                         Plot area 270(25.08 sq.m.)        2         2
# 3274  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
#
#      balcony           additionalRoom  \
# 30         2            not available
# 88         1                   others
# 2045       2  study room,servant room
# 2803       2            not available
# 2842       1            not available
# 2895       1            not available
# 2960       3            not available
# 3168       2            not available
# 3274       2               pooja room
#
#                                                 address  floorNum  \
# 30                    New Palam Vihar, Gurgaon, Haryana       1.0
# 88           F 150/b, New Palam Vihar, Gurgaon, Haryana       2.0
# 2045                      New Gurgaon, Gurgaon, Haryana       4.0
# 2803                      New Gurgaon, Gurgaon, Haryana       3.0
# 2842                  New Palam Vihar, Gurgaon, Haryana       1.0
# 2895                      New Gurgaon, Gurgaon, Haryana       7.0
# 2960                      New Gurgaon, Gurgaon, Haryana       3.0
# 3168         Ez-19 A, New Palam Vihar, Gurgaon, Haryana       3.0
# 3274  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...       1.0
#
#              facing       agePossession  \
# 30    not available     1 to 5 Year Old
# 88    not available     1 to 5 Year Old
# 2045  not available            Jun 2027
# 2803  not available     1 to 5 Year Old
# 2842  not available     0 to 1 Year Old
# 2895  not available  Under Construction
# 2960  not available    5 to 10 Year Old
# 3168           west    5 to 10 Year Old
# 3274          north        10+ Year Old
#
#                                         nearbyLocations  \
# 30    ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 88    ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2045  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2803  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2842  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2895  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 2960  ['Columbia Asia Hospital', 'Apex Multi Special...
# 3168  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3274  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 30    We are the proud owners of this 2 bhk apartmen...
# 88    2 bhk room with wooden coverd ,1 drawing room,...
# 2045  This lovely 4 bhk apartment/flat in new gurgao...
# 2803  Check out this 2 bhk apartment for sale in tak...
# 2842  Cctv surveillance are provided here. There is ...
# 2895  We are the proud owners of this 2 bhk apartmen...
# 2960  Located in the popular residential address of ...
# 3168  There are availability of various facilities l...
# 3274  Ground and first floor, Ground floor: Ground f...
#
#                                          furnishDetails  \
# 30                                                  NaN
# 88    ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2045  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2803                                                 []
# 2842  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2895                                                 []
# 2960                                                 []
# 3168  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 3274                                                NaN
#
#                                                features  \
# 30                                                  NaN
# 88                            ['Water Storage', 'Park']
# 2045  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2803  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...
# 2842                                                NaN
# 2895  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
# 2960                                                NaN
# 3168       ['Water Storage', 'Park', 'Visitor Parking']
# 3274                                                NaN
#
#                                                  rating
# 30    ['Environment4 out of 5', 'Safety4 out of 5', ...
# 88    ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2045                                                NaN
# 2803                                                NaN
# 2842  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2895                                                NaN
# 2960                                                NaN
# 3168  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3274  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df.loc[30,'sector'] = 'sector 110'
df.loc[88,'sector'] = 'sector 110'
df.loc[2045,'sector'] = 'sector 76'
df.loc[2803,'sector'] = 'sector 37'
df.loc[2842,'sector'] = 'sector 110'
df.loc[2895,'sector'] = 'sector 90'
df.loc[2960,'sector'] = 'sector 92'
df.loc[3168,'sector'] = 'sector 110'
df.loc[3274,'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3844, 21)

# %%
# Filter the DataFrame to show rows that do not contain the word 'sector'
filtered_df = df[~df['sector'].str.contains('sector', case=False)]
filtered_df['sector'].unique()
# Out:
# array([], dtype=object)

# %%
df.shape
# Out:
# (3844, 21)

# %%
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df['society'].value_counts().head(3)
# Out:
# society
# independent     514
# tulip violet     75
# ss the leaf      74
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(124)

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
